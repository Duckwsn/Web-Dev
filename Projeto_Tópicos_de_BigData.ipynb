# %% [markdown]
# <a href="https://colab.research.google.com/github/Duckwsn/Web-Dev/blob/main/Projeto_T%C3%B3picos_de_BigData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as ny
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/Trabalho.csv", header=0)

df.head()
# Out:
#   "raiva" "leishmaniose" "espécie"  "ano" "cura_leishmaniose" "cura_raiva"  \
# 0      29           3564    humana   2002                  //           //
# 1      22          3,565    humana   2003                  //           //
# 2      20          3,659    humana   2004                  //           //
# 3       1          3,568    humana   2005                  //           //
# 4       4          3,560    humana   2006                  //           //
#
#   "óbitos_leishmaniose" "óbitos_raiva  Unnamed: 8  Unnamed: 9 Unnamed: 10
# 0                    //            29         NaN         NaN         NaN
# 1                    //            22         NaN         NaN         NaN
# 2                    //            20         NaN         NaN         NaN
# 3                    //             1         NaN         NaN         NaN
# 4                    //             4         NaN         NaN         NaN

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   "raiva"                24 non-null     object
#  1   "leishmaniose"         24 non-null     object
#  2   "espécie"              24 non-null     object
#  3   "ano"                  24 non-null     int64
#  4   "cura_leishmaniose"    24 non-null     object
#  5   "cura_raiva"           24 non-null     object
#  6   "óbitos_leishmaniose"  24 non-null     object
#  7   "óbitos_raiva          24 non-null     object
#  8   Unnamed: 8             0 non-null      float64
#  9   Unnamed: 9             0 non-null      float64
#  10  Unnamed: 10            1 non-null      object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 2.2+ KB

# %%
df.describe()
# Out:
#              "ano"  Unnamed: 8  Unnamed: 9
# count    24.000000         0.0         0.0
# mean   2013.500000         NaN         NaN
# std       7.071068         NaN         NaN
# min    2002.000000         NaN         NaN
# 25%    2007.750000         NaN         NaN
# 50%    2013.500000         NaN         NaN
# 75%    2019.250000         NaN         NaN
# max    2025.000000         NaN         NaN

# %%
df.isnull().sum()
# Out:
# "raiva"                   0
# "leishmaniose"            0
# "espécie"                 0
# "ano"                     0
# "cura_leishmaniose"       0
# "cura_raiva"              0
# "óbitos_leishmaniose"     0
# "óbitos_raiva             0
# Unnamed: 8               24
# Unnamed: 9               24
# Unnamed: 10              23
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['"raiva"', '"leishmaniose"', '"espécie"', '"ano"',
#        '"cura_leishmaniose"', '"cura_raiva"', '"óbitos_leishmaniose"',
#        '"óbitos_raiva', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'],
#       dtype='object')

# %%
print(df.head(10))
# Out:
#   "raiva" "leishmaniose" "espécie"  "ano" "cura_leishmaniose" "cura_raiva"  \
# 0      29           3564    humana   2002                  //           //
# 1      22          3,565    humana   2003                  //           //
# 2      20          3,659    humana   2004                  //           //
# 3       1          3,568    humana   2005                  //           //
# 4       4          3,560    humana   2006                  //           //
# 5      //           3204    humana   2007                2409           //
# 6       3           3381    humana   2008                2462            1
# 7       2           3557    humana   2009                2506           //
# 8       3           3433    humana   2010                2542           //
# 9       2           3816    humana   2011                2918           //
#
#   "óbitos_leishmaniose" "óbitos_raiva  Unnamed: 8  Unnamed: 9 Unnamed: 10
# 0                    //            29         NaN         NaN         NaN
# 1                    //            22         NaN         NaN         NaN
# 2                    //            20         NaN         NaN         NaN
# 3                    //             1         NaN         NaN         NaN
# 4                    //             4         NaN         NaN         NaN
# 5                   170            //         NaN         NaN         NaN
# 6                   191             2         NaN         NaN         NaN
# 7                   205             2         NaN         NaN         NaN
# 8                   210             3         NaN         NaN         NaN
# 9                   250             2         NaN         NaN         NaN

# %%
print(df.tail(10))
# Out:
#    "raiva" "leishmaniose" "espécie"  "ano" "cura_leishmaniose" "cura_raiva"  \
# 14       2           3127    humana   2016                2189           //
# 15       6           4103    humana   2017                2903            1
# 16      11           3567    humana   2018                2517           //
# 17       1           2220    humana   2019                1523           //
# 18       2           1933    humana   2020                1259           //
# 19       1           1683    humana   2021                1140           //
# 20       5           1684    humana   2022                1107           //
# 21       2           1461    humana   2023                 945           //
# 22       2            482    humana   2024                 248           //
# 23       2             //    humana   2025                  //           //
#
#    "óbitos_leishmaniose" "óbitos_raiva  Unnamed: 8  Unnamed: 9 Unnamed: 10
# 14                   252             2         NaN         NaN         NaN
# 15                   317             5         NaN         NaN         NaN
# 16                   280            11         NaN         NaN         NaN
# 17                   169             1         NaN         NaN         NaN
# 18                   157             2         NaN         NaN         NaN
# 19                   164             1         NaN         NaN         NaN
# 20                   165             5         NaN         NaN
# 21                   123             2         NaN         NaN         NaN
# 22                    41             2         NaN         NaN         NaN
# 23                    //             2         NaN         NaN         NaN

# %%
df.replace("//", ny.nan, inplace=True)

# %%
df.head()
# Out:
#   "raiva" "leishmaniose" "espécie"  "ano" "cura_leishmaniose" "cura_raiva"  \
# 0      29           3564    humana   2002                 NaN          NaN
# 1      22          3,565    humana   2003                 NaN          NaN
# 2      20          3,659    humana   2004                 NaN          NaN
# 3       1          3,568    humana   2005                 NaN          NaN
# 4       4          3,560    humana   2006                 NaN          NaN
#
#   "óbitos_leishmaniose" "óbitos_raiva  Unnamed: 8  Unnamed: 9 Unnamed: 10
# 0                   NaN            29         NaN         NaN         NaN
# 1                   NaN            22         NaN         NaN         NaN
# 2                   NaN            20         NaN         NaN         NaN
# 3                   NaN             1         NaN         NaN         NaN
# 4                   NaN             4         NaN         NaN         NaN

# %%
print(df.shape)
# Out:
# (24, 11)

# %%
print(df.columns)
# Out:
# Index(['"raiva"', '"leishmaniose"', '"espécie"', '"ano"',
#        '"cura_leishmaniose"', '"cura_raiva"', '"óbitos_leishmaniose"',
#        '"óbitos_raiva', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'],
#       dtype='object')

# %%
df.columns = [col.strip().replace('"', '') for col in df.columns]
df.columns = [col.strip() for col in df.columns]
df.columns
# Out:
# Index(['raiva', 'leishmaniose', 'espécie', 'ano', 'cura_leishmaniose',
#        'cura_raiva', 'óbitos_leishmaniose', 'óbitos_raiva', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10'],
#       dtype='object')

# %%
cura_leishmaniose = df['cura_leishmaniose']

print(cura_leishmaniose.unique())
# Out:
# [nan '2409' '2462' '2506' '2542' '2918' '2132' '2206' '2239' '2252' '2189'
#  '2903' '2517' '1523' '1259' '1140' '1107' '945' '248']

# %%
print(cura_leishmaniose.nunique())
# Out:
# 18

# %%
print(cura_leishmaniose.value_counts())
# Out:
# cura_leishmaniose
# 2409    1
# 2462    1
# 2506    1
# 2542    1
# 2918    1
# 2132    1
# 2206    1
# 2239    1
# 2252    1
# 2189    1
# 2903    1
# 2517    1
# 1523    1
# 1259    1
# 1140    1
# 1107    1
# 945     1
# 248     1
# Name: count, dtype: int64

# %%
ano = df.sort_values(by='ano', ascending=True)

print(ano)
# Out:
#    raiva leishmaniose espécie   ano cura_leishmaniose cura_raiva  \
# 0     29         3564  humana  2002               NaN        NaN
# 1     22        3,565  humana  2003               NaN        NaN
# 2     20        3,659  humana  2004               NaN        NaN
# 3      1        3,568  humana  2005               NaN        NaN
# 4      4        3,560  humana  2006               NaN        NaN
# 5    NaN         3204  humana  2007              2409        NaN
# 6      3         3381  humana  2008              2462          1
# 7      2         3557  humana  2009              2506        NaN
# 8      3         3433  humana  2010              2542        NaN
# 9      2         3816  humana  2011              2918        NaN
# 10     5         2953  humana  2012              2132        NaN
# 11     5         3183  humana  2013              2206        NaN
# 12     0         3362  humana  2014              2239        NaN
# 13     2         3223  humana  2015              2252        NaN
# 14     2         3127  humana  2016              2189        NaN
# 15     6         4103  humana  2017              2903          1
# 16    11         3567  humana  2018              2517        NaN
# 17     1         2220  humana  2019              1523        NaN
# 18     2         1933  humana  2020              1259        NaN
# 19     1         1683  humana  2021              1140        NaN
# 20     5         1684  humana  2022              1107        NaN
# 21     2         1461  humana  2023               945        NaN
# 22     2          482  humana  2024               248        NaN
# 23     2          NaN  humana  2025               NaN        NaN
#
#    óbitos_leishmaniose óbitos_raiva  Unnamed: 8  Unnamed: 9 Unnamed: 10
# 0                  NaN           29         NaN         NaN         NaN
# 1                  NaN           22         NaN         NaN         NaN
# 2                  NaN           20         NaN         NaN         NaN
# 3                  NaN            1         NaN         NaN         NaN
# 4                  NaN            4         NaN         NaN         NaN
# 5                  170          NaN         NaN         NaN         NaN
# 6                  191            2         NaN         NaN         NaN
# 7                  205            2         NaN         NaN         NaN
# 8                  210            3         NaN         NaN         NaN
# 9                  250            2         NaN         NaN         NaN
# 10                 201            5         NaN         NaN         NaN
# 11                 216            5         NaN         NaN         NaN
# 12                 227            0         NaN         NaN         NaN
# 13                 246            2         NaN         NaN         NaN
# 14                 252            2         NaN         NaN         NaN
# 15                 317            5         NaN         NaN         NaN
# 16                 280           11         NaN         NaN         NaN
# 17                 169            1         NaN         NaN         NaN
# 18                 157            2         NaN         NaN         NaN
# 19                 164            1         NaN         NaN         NaN
# 20                 165            5         NaN         NaN
# 21                 123            2         NaN         NaN         NaN
# 22                  41            2         NaN         NaN         NaN
# 23                 NaN            2         NaN         NaN         NaN

# %%
ano = df.sort_values(by='ano', ascending=False)

print(ano)
# Out:
#    raiva leishmaniose espécie   ano cura_leishmaniose cura_raiva  \
# 23     2          NaN  humana  2025               NaN        NaN
# 22     2          482  humana  2024               248        NaN
# 21     2         1461  humana  2023               945        NaN
# 20     5         1684  humana  2022              1107        NaN
# 19     1         1683  humana  2021              1140        NaN
# 18     2         1933  humana  2020              1259        NaN
# 17     1         2220  humana  2019              1523        NaN
# 16    11         3567  humana  2018              2517        NaN
# 15     6         4103  humana  2017              2903          1
# 14     2         3127  humana  2016              2189        NaN
# 13     2         3223  humana  2015              2252        NaN
# 12     0         3362  humana  2014              2239        NaN
# 11     5         3183  humana  2013              2206        NaN
# 10     5         2953  humana  2012              2132        NaN
# 9      2         3816  humana  2011              2918        NaN
# 8      3         3433  humana  2010              2542        NaN
# 7      2         3557  humana  2009              2506        NaN
# 6      3         3381  humana  2008              2462          1
# 5    NaN         3204  humana  2007              2409        NaN
# 4      4        3,560  humana  2006               NaN        NaN
# 3      1        3,568  humana  2005               NaN        NaN
# 2     20        3,659  humana  2004               NaN        NaN
# 1     22        3,565  humana  2003               NaN        NaN
# 0     29         3564  humana  2002               NaN        NaN
#
#    óbitos_leishmaniose óbitos_raiva  Unnamed: 8  Unnamed: 9 Unnamed: 10
# 23                 NaN            2         NaN         NaN         NaN
# 22                  41            2         NaN         NaN         NaN
# 21                 123            2         NaN         NaN         NaN
# 20                 165            5         NaN         NaN
# 19                 164            1         NaN         NaN         NaN
# 18                 157            2         NaN         NaN         NaN
# 17                 169            1         NaN         NaN         NaN
# 16                 280           11         NaN         NaN         NaN
# 15                 317            5         NaN         NaN         NaN
# 14                 252            2         NaN         NaN         NaN
# 13                 246            2         NaN         NaN         NaN
# 12                 227            0         NaN         NaN         NaN
# 11                 216            5         NaN         NaN         NaN
# 10                 201            5         NaN         NaN         NaN
# 9                  250            2         NaN         NaN         NaN
# 8                  210            3         NaN         NaN         NaN
# 7                  205            2         NaN         NaN         NaN
# 6                  191            2         NaN         NaN         NaN
# 5                  170          NaN         NaN         NaN         NaN
# 4                  NaN            4         NaN         NaN         NaN
# 3                  NaN            1         NaN         NaN         NaN
# 2                  NaN           20         NaN         NaN         NaN
# 1                  NaN           22         NaN         NaN         NaN
# 0                  NaN           29         NaN         NaN         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   raiva                23 non-null     object
#  1   leishmaniose         23 non-null     object
#  2   espécie              24 non-null     object
#  3   ano                  24 non-null     int64
#  4   cura_leishmaniose    18 non-null     object
#  5   cura_raiva           2 non-null      object
#  6   óbitos_leishmaniose  18 non-null     object
#  7   óbitos_raiva         23 non-null     object
#  8   Unnamed: 8           0 non-null      float64
#  9   Unnamed: 9           0 non-null      float64
#  10  Unnamed: 10          1 non-null      object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 2.2+ KB

# %%
df['raiva'] = pd.to_numeric(df['raiva'], errors='coerce')
df['leishmaniose'] = pd.to_numeric(df['leishmaniose'], errors='coerce')

# %%
plt.figure(figsize=(10,5))
plt.plot(df['ano'], df['raiva'], label='Casos de Raiva', marker='o')
plt.plot(df['ano'], df['leishmaniose'], label='Casos de Leishmaniose', marker='s')
plt.title("Casos de Raiva e Leishmaniose por Ano")
plt.xlabel("Ano")
plt.ylabel("Número de Casos")
plt.legend()
plt.grid(True)
plt.show()

# %%
df['óbitos_raiva'] = pd.to_numeric(df['óbitos_raiva'], errors='coerce')
df['óbitos_leishmaniose'] = pd.to_numeric(df['óbitos_leishmaniose'], errors='coerce')

plt.figure(figsize=(10,5))
plt.bar(df['ano'], df['óbitos_raiva'], width=0.4, label='Óbitos Raiva')
plt.bar(df['ano'] + 0.2, df['óbitos_leishmaniose'], width=0.4, label='Óbitos Leishmaniose')
plt.title("Óbitos por Ano")
plt.xlabel("Ano")
plt.ylabel("Número de Óbitos")
plt.legend()
plt.grid(True, axis='y')
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(df['leishmaniose'], df['óbitos_leishmaniose'], color='red', label='Leishmaniose')
plt.scatter(df['raiva'], df['óbitos_raiva'], color='blue', label='Raiva')
plt.xlabel("Casos")
plt.ylabel("Óbitos")
plt.title("Relação entre Casos e Óbitos")
plt.legend()
plt.grid(True)
plt.show()

# %%
df['cura_leishmaniose'] = pd.to_numeric(df['cura_leishmaniose'], errors='coerce')
df['cura_raiva'] = pd.to_numeric(df['cura_raiva'], errors='coerce')

total_cura_leish = df['cura_leishmaniose'].sum()
total_cura_raiva = df['cura_raiva'].sum()

valores = [total_cura_leish, total_cura_raiva]
labels = ['Cura Leishmaniose', 'Cura Raiva']

plt.figure(figsize=(6,6))
plt.pie(valores, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title("Proporção de Casos Curados")
plt.show()

# %%
df['cura_leishmaniose'] = pd.to_numeric(df['cura_leishmaniose'], errors='coerce')
df['cura_raiva'] = pd.to_numeric(df['cura_raiva'], errors='coerce')

plt.figure(figsize=(12,6))
plt.plot(df['ano'], df['raiva'], marker='o', label='Casos Raiva')
plt.plot(df['ano'], df['cura_raiva'], marker='s', label='Cura Raiva')
plt.plot(df['ano'], df['óbitos_raiva'], marker='^', label='Óbitos Raiva')

plt.plot(df['ano'], df['leishmaniose'], marker='o', linestyle='--', label='Casos Leishmaniose')
plt.plot(df['ano'], df['cura_leishmaniose'], marker='s', linestyle='--', label='Cura Leishmaniose')
plt.plot(df['ano'], df['óbitos_leishmaniose'], marker='^', linestyle='--', label='Óbitos Leishmaniose')

plt.title("Comparativo Geral — Casos, Curas e Óbitos")
plt.xlabel("Ano")
plt.ylabel("Quantidade")
plt.legend()
plt.grid(True)
plt.show()

# %%
df_filtro = df[df['raiva'] > 10]
df_filtro
# Out:
#     raiva  leishmaniose espécie   ano  cura_leishmaniose  cura_raiva  \
# 0    29.0        3564.0  humana  2002                NaN         NaN
# 1    22.0           NaN  humana  2003                NaN         NaN
# 2    20.0           NaN  humana  2004                NaN         NaN
# 16   11.0        3567.0  humana  2018             2517.0         NaN
#
#     óbitos_leishmaniose  óbitos_raiva  Unnamed: 8  Unnamed: 9 Unnamed: 10
# 0                   NaN          29.0         NaN         NaN         NaN
# 1                   NaN          22.0         NaN         NaN         NaN
# 2                   NaN          20.0         NaN         NaN         NaN
# 16                280.0          11.0         NaN         NaN         NaN

# %%
df_filtro2 = df[(df['raiva'] > 10) & (df['leishmaniose'] > 5)]
df_filtro2
# Out:
#     raiva  leishmaniose espécie   ano  cura_leishmaniose  cura_raiva  \
# 0    29.0        3564.0  humana  2002                NaN         NaN
# 16   11.0        3567.0  humana  2018             2517.0         NaN
#
#     óbitos_leishmaniose  óbitos_raiva  Unnamed: 8  Unnamed: 9 Unnamed: 10
# 0                   NaN          29.0         NaN         NaN         NaN
# 16                280.0          11.0         NaN         NaN         NaN

# %%
df_simpli = df[['ano', 'espécie', 'raiva', 'leishmaniose']]
df_simpli.head()
# Out:
#     ano espécie  raiva  leishmaniose
# 0  2002  humana   29.0        3564.0
# 1  2003  humana   22.0           NaN
# 2  2004  humana   20.0           NaN
# 3  2005  humana    1.0           NaN
# 4  2006  humana    4.0           NaN

# %%
df_nulos = df[df['cura_leishmaniose'].isnull()]

df_valores = df[df['cura_leishmaniose'].notnull()]

# %%
print(df_nulos)
# Out:
#     raiva  leishmaniose espécie   ano  cura_leishmaniose  cura_raiva  \
# 0    29.0        3564.0  humana  2002                NaN         NaN
# 1    22.0           NaN  humana  2003                NaN         NaN
# 2    20.0           NaN  humana  2004                NaN         NaN
# 3     1.0           NaN  humana  2005                NaN         NaN
# 4     4.0           NaN  humana  2006                NaN         NaN
# 23    2.0           NaN  humana  2025                NaN         NaN
#
#     óbitos_leishmaniose  óbitos_raiva  Unnamed: 8  Unnamed: 9 Unnamed: 10
# 0                   NaN          29.0         NaN         NaN         NaN
# 1                   NaN          22.0         NaN         NaN         NaN
# 2                   NaN          20.0         NaN         NaN         NaN
# 3                   NaN           1.0         NaN         NaN         NaN
# 4                   NaN           4.0         NaN         NaN         NaN
# 23                  NaN           2.0         NaN         NaN         NaN

# %%
print(df_valores)
# Out:
#     raiva  leishmaniose espécie   ano  cura_leishmaniose  cura_raiva  \
# 5     NaN        3204.0  humana  2007             2409.0         NaN
# 6     3.0        3381.0  humana  2008             2462.0         1.0
# 7     2.0        3557.0  humana  2009             2506.0         NaN
# 8     3.0        3433.0  humana  2010             2542.0         NaN
# 9     2.0        3816.0  humana  2011             2918.0         NaN
# 10    5.0        2953.0  humana  2012             2132.0         NaN
# 11    5.0        3183.0  humana  2013             2206.0         NaN
# 12    0.0        3362.0  humana  2014             2239.0         NaN
# 13    2.0        3223.0  humana  2015             2252.0         NaN
# 14    2.0        3127.0  humana  2016             2189.0         NaN
# 15    6.0        4103.0  humana  2017             2903.0         1.0
# 16   11.0        3567.0  humana  2018             2517.0         NaN
# 17    1.0        2220.0  humana  2019             1523.0         NaN
# 18    2.0        1933.0  humana  2020             1259.0         NaN
# 19    1.0        1683.0  humana  2021             1140.0         NaN
# 20    5.0        1684.0  humana  2022             1107.0         NaN
# 21    2.0        1461.0  humana  2023              945.0         NaN
# 22    2.0         482.0  humana  2024              248.0         NaN
#
#     óbitos_leishmaniose  óbitos_raiva  Unnamed: 8  Unnamed: 9 Unnamed: 10
# 5                 170.0           NaN         NaN         NaN         NaN
# 6                 191.0           2.0         NaN         NaN         NaN
# 7                 205.0           2.0         NaN         NaN         NaN
# 8                 210.0           3.0         NaN         NaN         NaN
# 9                 250.0           2.0         NaN         NaN         NaN
# 10                201.0           5.0         NaN         NaN         NaN
# 11                216.0           5.0         NaN         NaN         NaN
# 12                227.0           0.0         NaN         NaN         NaN
# 13                246.0           2.0         NaN         NaN         NaN
# 14                252.0           2.0         NaN         NaN         NaN
# 15                317.0           5.0         NaN         NaN         NaN
# 16                280.0          11.0         NaN         NaN         NaN
# 17                169.0           1.0         NaN         NaN         NaN
# 18                157.0           2.0         NaN         NaN         NaN
# 19                164.0           1.0         NaN         NaN         NaN
# 20                165.0           5.0         NaN         NaN
# 21                123.0           2.0         NaN         NaN         NaN
# 22                 41.0           2.0         NaN         NaN         NaN

# %%
df.describe()

media_leishmaniose = df['leishmaniose'].mean()
mediana_leishmaniose = df['leishmaniose'].median()
desvio_leishmaniose = df['leishmaniose'].std()

print(f"Média: {media_leishmaniose:.2f}")
print(f"Mediana: {mediana_leishmaniose:.2f}")
print(f"Desvio padrão: {desvio_leishmaniose:.2f}")
# Out:
# Média: 2838.74
# Mediana: 3204.00
# Desvio padrão: 968.02

# %%
df['casos_nao_curados_leishmaniose'] = df['leishmaniose'] - df['cura_leishmaniose']

df['situação_leishmaniose'] = ny.where(df['óbitos_leishmaniose'] > 0, 'Com óbitos', 'Sem óbitos')

df.head(100)
# Out:
#     raiva  leishmaniose espécie   ano  cura_leishmaniose  cura_raiva  \
# 0    29.0        3564.0  humana  2002                NaN         NaN
# 1    22.0           NaN  humana  2003                NaN         NaN
# 2    20.0           NaN  humana  2004                NaN         NaN
# 3     1.0           NaN  humana  2005                NaN         NaN
# 4     4.0           NaN  humana  2006                NaN         NaN
# 5     NaN        3204.0  humana  2007             2409.0         NaN
# 6     3.0        3381.0  humana  2008             2462.0         1.0
# 7     2.0        3557.0  humana  2009             2506.0         NaN
# 8     3.0        3433.0  humana  2010             2542.0         NaN
# 9     2.0        3816.0  humana  2011             2918.0         NaN
# 10    5.0        2953.0  humana  2012             2132.0         NaN
# 11    5.0        3183.0  humana  2013             2206.0         NaN
# 12    0.0        3362.0  humana  2014             2239.0         NaN
# 13    2.0        3223.0  humana  2015             2252.0         NaN
# 14    2.0        3127.0  humana  2016             2189.0         NaN
# 15    6.0        4103.0  humana  2017             2903.0         1.0
# 16   11.0        3567.0  humana  2018             2517.0         NaN
# 17    1.0        2220.0  humana  2019             1523.0         NaN
# 18    2.0        1933.0  humana  2020             1259.0         NaN
# 19    1.0        1683.0  humana  2021             1140.0         NaN
# 20    5.0        1684.0  humana  2022             1107.0         NaN
# 21    2.0        1461.0  humana  2023              945.0         NaN
# 22    2.0         482.0  humana  2024              248.0         NaN
# 23    2.0           NaN  humana  2025                NaN         NaN
#
#     óbitos_leishmaniose  óbitos_raiva  Unnamed: 8  Unnamed: 9 Unnamed: 10  \
# 0                   NaN          29.0         NaN         NaN         NaN
# 1                   NaN          22.0         NaN         NaN         NaN
# 2                   NaN          20.0         NaN         NaN         NaN
# 3                   NaN           1.0         NaN         NaN         NaN
# 4                   NaN           4.0         NaN         NaN         NaN
# 5                 170.0           NaN         NaN         NaN         NaN
# 6                 191.0           2.0         NaN         NaN         NaN
# 7                 205.0           2.0         NaN         NaN         NaN
# 8                 210.0           3.0         NaN         NaN         NaN
# 9                 250.0           2.0         NaN         NaN         NaN
# 10                201.0           5.0         NaN         NaN         NaN
# 11                216.0           5.0         NaN         NaN         NaN
# 12                227.0           0.0         NaN         NaN         NaN
# 13                246.0           2.0         NaN         NaN         NaN
# 14                252.0           2.0         NaN         NaN         NaN
# 15                317.0           5.0         NaN         NaN         NaN
# 16                280.0          11.0         NaN         NaN         NaN
# 17                169.0           1.0         NaN         NaN         NaN
# 18                157.0           2.0         NaN         NaN         NaN
# 19                164.0           1.0         NaN         NaN         NaN
# 20                165.0           5.0         NaN         NaN
# 21                123.0           2.0         NaN         NaN         NaN
# 22                 41.0           2.0         NaN         NaN         NaN
# 23                  NaN           2.0         NaN         NaN         NaN
#
#     casos_nao_curados_leishmaniose situação_leishmaniose
# 0                              NaN            Sem óbitos
# 1                              NaN            Sem óbitos
# 2                              NaN            Sem óbitos
# 3                              NaN            Sem óbitos
# 4                              NaN            Sem óbitos
# 5                            795.0            Com óbitos
# 6                            919.0            Com óbitos
# 7                           1051.0            Com óbitos
# 8                            891.0            Com óbitos
# 9                            898.0            Com óbitos
# 10                           821.0            Com óbitos
# 11                           977.0            Com óbitos
# 12                          1123.0            Com óbitos
# 13                           971.0            Com óbitos
# 14                           938.0            Com óbitos
# 15                          1200.0            Com óbitos
# 16                          1050.0            Com óbitos
# 17                           697.0            Com óbitos
# 18                           674.0            Com óbitos
# 19                           543.0            Com óbitos
# 20                           577.0            Com óbitos
# 21                           516.0            Com óbitos
# 22                           234.0            Com óbitos
# 23                             NaN            Sem óbitos

# %%
df_ordenado = df.sort_values(by='raiva', ascending=False)
df_ordenado.head()
# Out:
#     raiva  leishmaniose espécie   ano  cura_leishmaniose  cura_raiva  \
# 0    29.0        3564.0  humana  2002                NaN         NaN
# 1    22.0           NaN  humana  2003                NaN         NaN
# 2    20.0           NaN  humana  2004                NaN         NaN
# 16   11.0        3567.0  humana  2018             2517.0         NaN
# 15    6.0        4103.0  humana  2017             2903.0         1.0
#
#     óbitos_leishmaniose  óbitos_raiva  Unnamed: 8  Unnamed: 9 Unnamed: 10  \
# 0                   NaN          29.0         NaN         NaN         NaN
# 1                   NaN          22.0         NaN         NaN         NaN
# 2                   NaN          20.0         NaN         NaN         NaN
# 16                280.0          11.0         NaN         NaN         NaN
# 15                317.0           5.0         NaN         NaN         NaN
#
#     casos_nao_curados_leishmaniose situação_leishmaniose
# 0                              NaN            Sem óbitos
# 1                              NaN            Sem óbitos
# 2                              NaN            Sem óbitos
# 16                          1050.0            Com óbitos
# 15                          1200.0            Com óbitos

# %%
max_raiva = df['raiva'].max()
max_leishmaniose = df['leishmaniose'].max()
ano_max_raiva = df.loc[df['raiva'] == max_raiva, 'ano'].values[0]
ano_max_leishmaniose = df.loc[df['leishmaniose'] == max_leishmaniose, 'ano'].values[0]

print(f"Maior número de casos de raiva: {max_raiva} (Ano: {ano_max_raiva})")
print(f"Maior número de casos de leishmaniose: {max_leishmaniose} (Ano: {ano_max_leishmaniose})")
# Out:
# Maior número de casos de raiva: 29.0 (Ano: 2002)
# Maior número de casos de leishmaniose: 4103.0 (Ano: 2017)

# %%
resumo = {
    'Casos Totais Raiva': df['raiva'].sum(),
    'Casos Totais Leishmaniose': df['leishmaniose'].sum(),
    'Óbitos Totais Raiva': df['óbitos_raiva'].sum(),
    'Óbitos Totais Leishmaniose': df['óbitos_leishmaniose'].sum(),
    'Taxa média de cura Raiva (%)': (df['cura_raiva'].sum() / df['raiva'].sum()) * 100,
    'Taxa média de cura Leishmaniose (%)': (df['cura_leishmaniose'].sum() / df['leishmaniose'].sum()) * 100
}

for chave, valor in resumo.items():
    print(f"{chave}: {valor:.2f}")
# Out:
# Casos Totais Raiva: 132.00
# Casos Totais Leishmaniose: 53936.00
# Óbitos Totais Raiva: 130.00
# Óbitos Totais Leishmaniose: 3584.00
# Taxa média de cura Raiva (%): 1.52
# Taxa média de cura Leishmaniose (%): 65.81
